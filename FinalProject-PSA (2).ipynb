# %%
import pandas as pd
df = pd.read_csv("DogLicenses.csv", low_memory = False)
df.head(10)
# Out:
#        _id                              LicenseType                Breed  \
# 0  3878524                    Dog Individual Female            DACHSHUND
# 1  3878525                    Dog Individual Female       GREAT PYRENEES
# 2  3878526  Dog Senior Citizen or Disability Female         GOLDENDOODLE
# 3  3878527                      Dog Individual Male     GER SHEPHERD MIX
# 4  3878528  Dog Senior Citizen or Disability Female         MOUNTAIN CUR
# 5  3878529                    Dog Individual Female                BOXER
# 6  3878530                      Dog Individual Male    DOBERMAN PINSCHER
# 7  3878531                      Dog Individual Male         SHEPHERD MIX
# 8  3878532                    Dog Individual Female    DOBERMAN PINSCHER
# 9  3878533    Dog Senior Citizen or Disability Male  JACK RUSSEL TERRIER
#
#          Color  DogName  OwnerZip  ExpYear            ValidDate
# 0  BLACK/BROWN     LUNA     15214     2025  2024-12-02T08:20:05
# ...

# %%
ZiptoNeighborhood = {
    15201: "Lawrenceville",
    15202: "Avalon",
    15203: "South Side",
    15204: "Sheraden",
    15205: "Crafton Heights",
    15206: "East Liberty",
    15207: "Hazelwood",
    15208: "Point Breeze North",
    15209: "Millvale",
    15210: "Carrick",
    15211: "Mount Washington",
    15212: "North Side",
    15213: "Oakland",
    15214: "Perry North",
    15215: "Aspinwall",
    15216: "Beechview",
    15217: "Squirrel Hill",
    15218: "Edgewood",
    15219: "Hill District",
    15220: "West End",
    15221: "Regent Square",
    15222: "Downtown",
    15223: "Etna",
    15224: "Bloomfield",
    15225: "McKees Rocks",
    15226: "Brookline",
    15227: "Baldwin",
    15228: "Dormont",
    15229: "West View",
    15232: "Shadyside",
    15233: "North Shore",
    15234: "Castle Shannon",
    15235: "Penn Hills",
    15237: "Ross Township",
    15238: "Fox Chapel",
    15239: "Plum",
    15241: "Upper St. Clair",
    15242: "Green Tree",
    15243: "Mt. Lebanon"
}

# %%
#deletes any rows where trhe zipcode starts with 151
df = df[~df["OwnerZip"].astype(str).str.startswith("151")]

df["Neighborhood"] = df["OwnerZip"].map(ZiptoNeighborhood)
#Neighborhood column is created
print(df.columns)
print(df.head())
# Out:
# Index(['_id', 'LicenseType', 'Breed', 'Color', 'DogName', 'OwnerZip',
#        'ExpYear', 'ValidDate', 'Neighborhood'],
#       dtype='object')
#        _id                              LicenseType             Breed  \
# 0  3878524                    Dog Individual Female         DACHSHUND
# 1  3878525                    Dog Individual Female    GREAT PYRENEES
# 2  3878526  Dog Senior Citizen or Disability Female      GOLDENDOODLE
# 3  3878527                      Dog Individual Male  GER SHEPHERD MIX
# 5  3878529                    Dog Individual Female             BOXER
#
#          Color DogName  OwnerZip  ExpYear            ValidDate    Neighborhood
# 0  BLACK/BROWN    LUNA     15214     2025  2024-12-02T08:20:05     Perry North
# 1        WHITE   ELLIE     15214     2025  2024-12-02T08:20:05     Perry North
# 2        CREAM  DANCER     15234     2025  2024-12-02T08:45:20  Castle Shannon
# 3  BLACK/BROWN    THOR     15239     2025  2024-12-02T10:38:09            Plum
# ...

# %%
#counts the number of dog licenses per neighborhood
NeighborhoodCounts = df.groupby("Neighborhood").size().reset_index(name="Dog Licenses").sort_values(by = "Dog Licenses", ascending = False)

#displays the top 15 neighborhoods, exclude the first 7 because they are boroughs outside of Pittsburgh city
NeighborhoodCounts.iloc[7:30]
# Out:
#         Neighborhood  Dog Licenses
# 8    Crafton Heights          1044
# 38         West View          1018
# 30     Regent Square          1015
# 14        Fox Chapel           995
# 20          Millvale           925
# 22       Mt. Lebanon           917
# 7     Castle Shannon           870
# 3          Beechview           810
# 0          Aspinwall           786
# 37          West End           574
# 12          Edgewood           541
# 13              Etna           500
# 27       Perry North           278
# 24        North Side           178
# 6            Carrick           105
# 19      McKees Rocks            82
# 5          Brookline            77
# 16         Hazelwood            19
# 11      East Liberty            14
# 33          Sheraden            14
# 35     Squirrel Hill            12
# 21  Mount Washington            10
# 18     Lawrenceville             8

# %% [markdown]
# Conclusion: The best neighborhood based on my metric of registered dog licenses is Crafton Heights because it has the most licenses in terms of neighborhoods within the city of Pittsburgh. However, the overall best neighborhood in relation to the group metric would be East Liberty, even though it is not the first it is the 75th pecentaile with 14 registred licenses making it an okay neighborhood when it comes it its walkability.
