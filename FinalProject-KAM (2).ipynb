# %%
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("historicalSites3.csv")
data1 = data.drop(columns=['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'])
data2 = data1.rename(columns = {'Unnamed: 8' : 'Neighborhood'})
data2.head(3)
# Out:
#   City Designated Individual Historic Sites  Neighborhood
# 0                                       _id  neighborhood
# 1                                     12838   Perry North
# 2                                     12839     Beechview

# %%
nList = data2['Neighborhood'].unique()
nList
# Out:
# array(['neighborhood', 'Perry North', 'Beechview', 'Shadyside',
#        'Overbrook', 'Lower Lawrenceville', 'Squirrel Hill',
#        'Crawford-Roberts', 'South Side Flats',
#        'Central Business District', 'Greenfield', 'East Allegheny',
#        'Central Northside', 'Bloomfield', 'Middle Hill',
#        'Central Lawrenceville', 'Point Breeze',
#        'Lincoln-Lemington-Belmar', 'Bluff', 'Carrick', 'Friendship',
#        'Larimer', 'Allegheny Center', 'Polish Hill', 'Brighton Heights',
#        'Allegheny West', 'Homewood North', 'Lincoln Place',
#        'Homewood West', 'Troy Hill', 'Elliott', 'North Oakland',
#        'North Shore', 'Mount Washington', 'Sheraden', 'South Shore',
#        'Hazelwood', 'Highland Park', 'Fineview', 'Arlington Heights',
#        'Homewood South', 'Sheradan', 'East Liberty', 'West Oakland',
#        'Central Oakland', 'West End', 'Lawrenceville', 'Upper Hill',
#        'South Oakland', 'Garfield', 'Knoxville',
# ...

# %%
nLength = len(data2)
nLength
# Out:
# 146

# %%
nCount = data2.groupby('Neighborhood').count()
nCount
# Out:
#                            City Designated Individual Historic Sites
# Neighborhood
# Allegheny Center                                                   6
# Allegheny West                                                     4
# Arlington Heights                                                  1
# Beechview                                                          1
# Bloomfield                                                         3
# Bluff                                                              2
# Brighton Heights                                                   3
# Brookline                                                          2
# Carrick                                                            3
# Central Business District                                         11
# Central Lawrenceville                                              6
# Central Northside                                                  3
# ...
